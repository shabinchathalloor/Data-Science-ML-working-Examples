# %%
import numpy as np
import pandas as pd

# %%
#reading the csv files
df = pd.read_csv('adult_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education.num     32561 non-null int64
# marital.status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital.gain      32561 non-null int64
# capital.loss      32561 non-null int64
# hours.per.week    32561 non-null int64
# native.country    32561 non-null object
# income            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.info(verbose = False) # Print the short summary of the dataframe by setting verbose = False
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Columns: 15 entries, age to income
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        age         workclass  fnlwgt     education  education.num  \
# 0       90                 ?   77053       HS-grad              9
# 1       82           Private  132870       HS-grad              9
# 2       66                 ?  186061  Some-college             10
# 3       54           Private  140359       7th-8th              4
# 4       41           Private  264663  Some-college             10
# 5       34           Private  216864       HS-grad              9
# 6       38           Private  150601          10th              6
# 7       74         State-gov   88638     Doctorate             16
# 8       68       Federal-gov  422013       HS-grad              9
# 9       41           Private   70037  Some-college             10
# 10      45           Private  172274     Doctorate             16
# 11      38  Self-emp-not-inc  164526   Prof-school             15
# 12      52           Private  129177     Bachelors             13
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.workclass.describe()
# Out:
# count       32561
# unique          9
# top       Private
# freq        22696
# Name: workclass, dtype: object

# %%
df.fnlwgt.describe()
# Out:
# count    3.256100e+04
# mean     1.897784e+05
# std      1.055500e+05
# min      1.228500e+04
# 25%      1.178270e+05
# 50%      1.783560e+05
# 75%      2.370510e+05
# max      1.484705e+06
# Name: fnlwgt, dtype: float64

# %%
df.education.describe()
# Out:
# count       32561
# unique         16
# top       HS-grad
# freq        10501
# Name: education, dtype: object

# %%
df['education.num'].describe()
# Out:
# count    32561.000000
# mean        10.080679
# std          2.572720
# min          1.000000
# 25%          9.000000
# 50%         10.000000
# 75%         12.000000
# max         16.000000
# Name: education.num, dtype: float64

# %%
df['marital.status'].describe()
# Out:
# count                  32561
# unique                     7
# top       Married-civ-spouse
# freq                   14976
# Name: marital.status, dtype: object

# %%
df['capital.loss'].describe()
# Out:
# count    32561.000000
# mean        87.303830
# std        402.960219
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       4356.000000
# Name: capital.loss, dtype: float64

# %%
df['capital.gain'].describe()
# Out:
# count    32561.000000
# mean      1077.648844
# std       7385.292085
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      99999.000000
# Name: capital.gain, dtype: float64

# %%
df_1 = df[df.workclass=='?']
df_1
# Out:
#        age workclass  fnlwgt     education  education.num  \
# 0       90         ?   77053       HS-grad              9
# 2       66         ?  186061  Some-college             10
# 14      51         ?  172175     Doctorate             16
# 24      61         ?  135285       HS-grad              9
# 44      71         ?  100820       HS-grad              9
# 48      68         ?  192052  Some-college             10
# 49      67         ?  174995  Some-college             10
# 76      41         ?   27187     Assoc-voc             11
# 114     72         ?  118902     Doctorate             16
# 133     65         ?  240857     Bachelors             13
# 136     68         ?  257269     Bachelors             13
# 153     43         ?  152569     Assoc-voc             11
# 202     65         ?  143118       HS-grad              9
# 213     63         ?  234083       HS-grad              9
# 227     63         ?   83043     Bachelors             13
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1836 entries, 0 to 32544
# Data columns (total 15 columns):
# age               1836 non-null int64
# workclass         1836 non-null object
# fnlwgt            1836 non-null int64
# education         1836 non-null object
# education.num     1836 non-null int64
# marital.status    1836 non-null object
# occupation        1836 non-null object
# relationship      1836 non-null object
# race              1836 non-null object
# sex               1836 non-null object
# capital.gain      1836 non-null int64
# capital.loss      1836 non-null int64
# hours.per.week    1836 non-null int64
# native.country    1836 non-null object
# income            1836 non-null object
# dtypes: int64(6), object(9)
# memory usage: 229.5+ KB

# %%
df.head(10)
# Out:
#    age    workclass  fnlwgt     education  education.num marital.status  \
# 0   90            ?   77053       HS-grad              9        Widowed
# 1   82      Private  132870       HS-grad              9        Widowed
# 2   66            ?  186061  Some-college             10        Widowed
# 3   54      Private  140359       7th-8th              4       Divorced
# 4   41      Private  264663  Some-college             10      Separated
# 5   34      Private  216864       HS-grad              9       Divorced
# 6   38      Private  150601          10th              6      Separated
# 7   74    State-gov   88638     Doctorate             16  Never-married
# 8   68  Federal-gov  422013       HS-grad              9       Divorced
# 9   41      Private   70037  Some-college             10  Never-married
#
#           occupation    relationship   race     sex  capital.gain  \
# 0                  ?   Not-in-family  White  Female             0
# ...

# %%
df_1.info() #check the ? marked row nos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1836 entries, 0 to 32544
# Data columns (total 15 columns):
# age               1836 non-null int64
# workclass         1836 non-null object
# fnlwgt            1836 non-null int64
# education         1836 non-null object
# education.num     1836 non-null int64
# marital.status    1836 non-null object
# occupation        1836 non-null object
# relationship      1836 non-null object
# race              1836 non-null object
# sex               1836 non-null object
# capital.gain      1836 non-null int64
# capital.loss      1836 non-null int64
# hours.per.week    1836 non-null int64
# native.country    1836 non-null object
# income            1836 non-null object
# dtypes: int64(6), object(9)
# memory usage: 229.5+ KB

# %%
#dropping the rows having missing values in workclass
df_2 = df[df['workclass']!= '?']
df_2.head(20)
# Out:
#     age         workclass  fnlwgt     education  education.num  \
# 1    82           Private  132870       HS-grad              9
# 3    54           Private  140359       7th-8th              4
# 4    41           Private  264663  Some-college             10
# 5    34           Private  216864       HS-grad              9
# 6    38           Private  150601          10th              6
# 7    74         State-gov   88638     Doctorate             16
# 8    68       Federal-gov  422013       HS-grad              9
# 10   45           Private  172274     Doctorate             16
# 11   38  Self-emp-not-inc  164526   Prof-school             15
# 12   52           Private  129177     Bachelors             13
# 13   32           Private  136204       Masters             14
# 15   46           Private   45363   Prof-school             15
# 16   45           Private  172822          11th              7
# 17   57           Private  317847       Masters             14
# ...

# %%
df_3 = df[df['occupation']!= '?']

# %%
df_3.head(10)
# Out:
#     age         workclass  fnlwgt     education  education.num marital.status  \
# 1    82           Private  132870       HS-grad              9        Widowed
# 3    54           Private  140359       7th-8th              4       Divorced
# 4    41           Private  264663  Some-college             10      Separated
# 5    34           Private  216864       HS-grad              9       Divorced
# 6    38           Private  150601          10th              6      Separated
# 7    74         State-gov   88638     Doctorate             16  Never-married
# 8    68       Federal-gov  422013       HS-grad              9       Divorced
# 9    41           Private   70037  Some-college             10  Never-married
# 10   45           Private  172274     Doctorate             16       Divorced
# 11   38  Self-emp-not-inc  164526   Prof-school             15  Never-married
#
#            occupation    relationship   race     sex  capital.gain  \
# ...

# %%
df_4 = df[df['native.country']!= '?']
df_4.head(10)
# Out:
#     age    workclass  fnlwgt     education  education.num marital.status  \
# 0    90            ?   77053       HS-grad              9        Widowed
# 1    82      Private  132870       HS-grad              9        Widowed
# 2    66            ?  186061  Some-college             10        Widowed
# 3    54      Private  140359       7th-8th              4       Divorced
# 4    41      Private  264663  Some-college             10      Separated
# 5    34      Private  216864       HS-grad              9       Divorced
# 6    38      Private  150601          10th              6      Separated
# 7    74    State-gov   88638     Doctorate             16  Never-married
# 8    68  Federal-gov  422013       HS-grad              9       Divorced
# 10   45      Private  172274     Doctorate             16       Divorced
#
#            occupation    relationship   race     sex  capital.gain  \
# 0                   ?   Not-in-family  White  Female             0
# ...

# %%
df_5 = df[df['capital.gain'] ==0]
df_5
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 0       90                 ?   77053       HS-grad              9
# 1       82           Private  132870       HS-grad              9
# 2       66                 ?  186061  Some-college             10
# 3       54           Private  140359       7th-8th              4
# 4       41           Private  264663  Some-college             10
# 5       34           Private  216864       HS-grad              9
# 6       38           Private  150601          10th              6
# 7       74         State-gov   88638     Doctorate             16
# 8       68       Federal-gov  422013       HS-grad              9
# 9       41           Private   70037  Some-college             10
# 10      45           Private  172274     Doctorate             16
# 11      38  Self-emp-not-inc  164526   Prof-school             15
# 12      52           Private  129177     Bachelors             13
# ...

# %%
df_6 = df[df['capital.gain']!= 0]
df_6.head(10)
# Out:
#       age         workclass  fnlwgt     education  education.num  \
# 1519   54      Self-emp-inc  166459   Prof-school             15
# 1520   52           Private  152234       HS-grad              9
# 1521   53      Self-emp-inc  263925       HS-grad              9
# 1522   52           Private  118025     Bachelors             13
# 1523   46           Private  370119   Prof-school             15
# 1524   43           Private  176270     Bachelors             13
# 1525   49           Private  159816     Bachelors             13
# 1526   50           Private  171338  Some-college             10
# 1527   22  Self-emp-not-inc  202920       HS-grad              9
# 1528   43      Self-emp-inc  172826  Some-college             10
#
#           marital.status       occupation relationship                race  \
# 1519  Married-civ-spouse   Prof-specialty      Husband               White
# 1520  Married-civ-spouse  Exec-managerial      Husband  Asian-Pac-Islander
# ...

# %%
df_7 = df[df['capital.loss'] & df['capital.gain'] ==0]
df_7
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 0       90                 ?   77053       HS-grad              9
# 1       82           Private  132870       HS-grad              9
# 2       66                 ?  186061  Some-college             10
# 3       54           Private  140359       7th-8th              4
# 4       41           Private  264663  Some-college             10
# 5       34           Private  216864       HS-grad              9
# 6       38           Private  150601          10th              6
# 7       74         State-gov   88638     Doctorate             16
# 8       68       Federal-gov  422013       HS-grad              9
# 9       41           Private   70037  Some-college             10
# 10      45           Private  172274     Doctorate             16
# 11      38  Self-emp-not-inc  164526   Prof-school             15
# 12      52           Private  129177     Bachelors             13
# ...

# %%
df_8 = df[df['capital.loss'] &  df['capital.gain']!= 0] 
df_8.head(10)
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education.num, marital.status, occupation, relationship, race, sex, capital.gain, capital.loss, hours.per.week, native.country, income]
# Index: []

# %%
print("Median: ",df.age.median())
print("Mean: ",df.age.mean())
# Out:
# Median:  37.0
# Mean:  38.58164675532078

# %%
print("Median: ",df.fnlwgt.median())
print("Mean: ",df.fnlwgt.mean())
# Out:
# Median:  178356.0
# Mean:  189778.36651208502

# %%
print("Median: ",df['education.num'].median())
print("Mean: ",df['education.num'].mean())
# Out:
# Median:  10.0
# Mean:  10.0806793403151

# %%
print("Median: ",df['capital.gain'].median())
print("Mean: ",df['capital.gain'].mean())
# Out:
# Median:  0.0
# Mean:  1077.6488437087312

# %%
print("Median: ",df['capital.loss'].median())
print("Mean: ",df['capital.loss'].mean())
# Out:
# Median:  0.0
# Mean:  87.303829734959

# %%
print("Median: ",df['hours.per.week'].median())
print("Mean: ",df['hours.per.week'].mean())
# Out:
# Median:  40.0
# Mean:  40.437455852092995

# %%
df['native.country'].head(20)
# Out:
# 0     United-States
# 1     United-States
# 2     United-States
# 3     United-States
# 4     United-States
# 5     United-States
# 6     United-States
# 7     United-States
# 8     United-States
# 9                 ?
# 10    United-States
# 11    United-States
# 12    United-States
# 13    United-States
# 14    United-States
# 15    United-States
# 16    United-States
# 17    United-States
# 18                ?
# 19    United-States
# Name: native.country, dtype: object

# %%
#Replacing empty value with mean of native country

native_country_mean = df['native.country'].mode()
#native_country_mean[0]
df_9 = df['native.country'].replace(to_replace = '?', value = native_country_mean[0] )
df_9.head(20)
# Out:
# 0     United-States
# 1     United-States
# 2     United-States
# 3     United-States
# 4     United-States
# 5     United-States
# 6     United-States
# 7     United-States
# 8     United-States
# 9     United-States
# 10    United-States
# 11    United-States
# 12    United-States
# 13    United-States
# 14    United-States
# 15    United-States
# 16    United-States
# 17    United-States
# 18    United-States
# 19    United-States
# Name: native.country, dtype: object

# %%
df.occupation.head(20)
# Out:
# 0                     ?
# 1       Exec-managerial
# 2                     ?
# 3     Machine-op-inspct
# 4        Prof-specialty
# 5         Other-service
# 6          Adm-clerical
# 7        Prof-specialty
# 8        Prof-specialty
# 9          Craft-repair
# 10       Prof-specialty
# 11       Prof-specialty
# 12        Other-service
# 13      Exec-managerial
# 14                    ?
# 15       Prof-specialty
# 16     Transport-moving
# 17      Exec-managerial
# 18    Handlers-cleaners
# 19                Sales
# Name: occupation, dtype: object

# %%
#Replacing empty value with mean of occupation
occupation_mean = df['occupation'].mode()
occupation_mean
df_10 = df['occupation'].replace(to_replace = '?', value = occupation_mean[0] )
df_10.head(20)
# Out:
# 0        Prof-specialty
# 1       Exec-managerial
# 2        Prof-specialty
# 3     Machine-op-inspct
# 4        Prof-specialty
# 5         Other-service
# 6          Adm-clerical
# 7        Prof-specialty
# 8        Prof-specialty
# 9          Craft-repair
# 10       Prof-specialty
# 11       Prof-specialty
# 12        Other-service
# 13      Exec-managerial
# 14       Prof-specialty
# 15       Prof-specialty
# 16     Transport-moving
# 17      Exec-managerial
# 18    Handlers-cleaners
# 19                Sales
# Name: occupation, dtype: object

# %%
#slicing according to iloc for every 500th data of all colum
df.age.iloc[500]
# Out:
# 36

# %%
df.workclass.iloc[500]
# Out:
# 'Private'

# %%
df.fnlwgt.iloc[500]
# Out:
# 386726

# %%
print(df.education.iloc[500])
print(df['education.num'].iloc[500])
print(df['marital.status'].iloc[500])
print(df.occupation.iloc[500])
print(df.relationship.iloc[500])
print(df.race.iloc[500])
print(df.sex.iloc[500])
print(df['capital.gain'].iloc[500])
print(df['capital.loss'].iloc[500])
print(df['hours.per.week'].iloc[500])
print(df['native.country'].iloc[500])
print(df.income.iloc[500])
# Out:
# Masters
# 14
# Married-civ-spouse
# Prof-specialty
# Wife
# White
# Female
# 0
# 1977
# 44
# United-States
# >50K

# %%
df['capital.loss'].head(20)
# Out:
# 0     4356
# 1     4356
# 2     4356
# 3     3900
# 4     3900
# 5     3770
# 6     3770
# 7     3683
# 8     3683
# 9     3004
# 10    3004
# 11    2824
# 12    2824
# 13    2824
# 14    2824
# 15    2824
# 16    2824
# 17    2824
# 18    2824
# 19    2824
# Name: capital.loss, dtype: int64

# %%
#count of capital loss which is more than 3000
df_11 = df['capital.loss'] > 3000
df_11.count()
# Out:
# 32561
